# %%
import pandas as pd

df = pd.read_excel("Raisin_Dataset.xlsx")
df.sample(5)
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 259  40403       289.259316       179.223383      0.784922       41209
# 420  86421       367.170337       300.793986      0.573477       87929
# 255  41755       296.788376       184.191377      0.784115       43362
# 532  82161       441.795552       246.810056      0.829402       86909
# 663  81480       434.100259       242.701751      0.829106       84581
#
#        Extent  Perimeter    Class
# 259  0.722204    761.949  Kecimen
# 420  0.748623   1080.007  Kecimen
# 255  0.691331    804.559  Kecimen
# 532  0.630243   1222.158    Besni
# 663  0.674012   1162.370    Besni

# %%
df.shape
# Out:
# (900, 8)

# %%
X = df[["Area", "MajorAxisLength", "MinorAxisLength", "Eccentricity", "ConvexArea", "Extent", "Perimeter"]]
y = df["Class"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
from sklearn.svm import SVC

model = SVC(kernel="rbf")
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)

model.n_iter_
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.86      0.75      0.80        83
#      Kecimen       0.81      0.90      0.85        97
#
#     accuracy                           0.83       180
#    macro avg       0.83      0.82      0.82       180
# weighted avg       0.83      0.83      0.83       180
# array([229], dtype=int32)

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
log_model = LogisticRegression()
svc_model = SVC(kernel="rbf", probability=True)
dt_model = DecisionTreeClassifier()

# %%
vc = VotingClassifier(estimators=[
    ('lr', log_model),
    ('svc', svc_model),
    ('dt', dt_model)
], voting="soft")

vc.fit(X_train, y_train)

y_pred = vc.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.89      0.82      0.86        83
#      Kecimen       0.86      0.92      0.89        97
#
#     accuracy                           0.87       180
#    macro avg       0.88      0.87      0.87       180
# weighted avg       0.87      0.87      0.87       180
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
